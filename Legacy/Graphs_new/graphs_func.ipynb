# %%
from Func import Dissertation_Func_1D

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
model_05_01 = Dissertation_Func_1D(
    L=200, N=20001, T=200, dt=0.1, k = 1, alpha = 1,
    init_type="tanh", steepness=.85, perc=0.4,
    t_start=100, t_end=140, num_points=200
)
model_05_01.solve() 
model_05_01.estimate_wave_speed(plot=True)
model_05_01.plot_u_m_with_custom_style([0, 100,200, 300, 400, 500], head_length=1.5, head_width=.65)
# Out:
# Estimated speed = 0.1576, R² = 1.0000
# Estimated speed = 0.1576, R² = 1.0000

# %%
model_05_01 = Dissertation_Func_1D(
    L=200, N=20001, T=200, dt=0.1, k = 1000, alpha = 100, m0 = 0.2,
    init_type="tanh", steepness=.85, perc=0.4,
    t_start=100, t_end=140, num_points=200
)
model_05_01.solve() 
model_05_01.estimate_wave_speed(plot=True)
model_05_01.plot_u_m_with_custom_style([0, 100,200, 300, 400, 500], head_length=1.5, head_width=.65)
# Out:
# Estimated speed = 0.1903, R² = 1.0000
# Estimated speed = 0.1903, R² = 1.0000

# %%
model_02_01 = Dissertation_Func_1D(
    L=200, N=20001, T=200, dt=0.1, k = 10, alpha = 1,
    init_type="tanh", steepness=.85, perc=0.4, m0 = 0.2,
    t_start=100, t_end=140, num_points=200
)
model_02_01.solve() 
model_02_01.estimate_wave_speed(plot=True)
model_02_01.plot_u_m_with_custom_style([0, 100,200, 300, 400, 500], head_length=1.5, head_width=.65)
# Out:
# Estimated speed = 0.1614, R² = 1.0000
# Estimated speed = 0.1614, R² = 1.0000

# %%
model_02_01.plot_u_m_with_custom_style([0, 60, 90, 120, 150, 180], head_length=1.5, head_width=.65)
