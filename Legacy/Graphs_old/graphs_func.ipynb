# %%
from Func import Dissertation_Func_1D

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# <h2> M0 = 0.5 + alpha = 0.01

# %%
model_05_01 = Dissertation_Func_1D(
    L=200, N=5001, T=200, dt=0.1, k = 0.1, alpha=0.01,
    init_type="tanh", steepness=.85, perc=0.4,
    t_start=60, t_end=180, num_points=200
)
model_05_01.solve() 
model_05_01.estimate_wave_speed(plot=True)
model_05_01.plot_u_m_with_custom_style([0, 100,200, 300, 400, 500], head_length=1.5, head_width=.65)
# Out:
# Estimated speed = 0.8285, R² = 0.9990
# Estimated speed = 0.8285, R² = 0.9990

# %%
model_05_1 = Dissertation_Func_1D(
    L=200, N=5001, T=200, dt=0.1, k = 1, alpha=0.01, m0=0.5,
    init_type="tanh", steepness=.85, perc=0.4,
    t_start=60, t_end=180, num_points=200
)
model_05_1.solve() 
model_05_1.estimate_wave_speed(plot=True)
model_05_1.plot_u_m_with_custom_style([0, 100,200, 300, 400, 500], head_length=1.5, head_width=.65)
# Out:
# Estimated speed = 0.8336, R² = 0.9990
# Estimated speed = 0.8336, R² = 0.9990

# %%
model_05_10 = Dissertation_Func_1D(
    L=200, N=5001, T=200, dt=0.1, k = 10, alpha=0.01, m0=0.5,
    init_type="tanh", steepness=.85, perc=0.4,
    t_start=60, t_end=180, num_points=200
)
model_05_10.solve() 
model_05_10.estimate_wave_speed(plot=True)
model_05_10.plot_u_m_with_custom_style([0, 100,200, 300, 400, 500], head_length=1.5, head_width=.65)
# Out:
# Estimated speed = 0.8477, R² = 0.9992
# Estimated speed = 0.8477, R² = 0.9992

# %%
model_05_100 = Dissertation_Func_1D(
    L=200, N=5001, T=200, dt=0.01, k = 100, alpha=0.01, m0=0.5,
    init_type="tanh", steepness=.85, perc=0.4,
    t_start=60, t_end=180, num_points=200
)
model_05_100.solve() 
model_05_100.estimate_wave_speed(plot=True)
model_05_100.plot_u_m_with_custom_style([0, 100,200, 300, 400, 500], head_length=1.5, head_width=.65)
# Out:
# Estimated speed = 0.8679, R² = 0.9994
# Estimated speed = 0.8679, R² = 0.9994

# %%
model_05_100_a100 = Dissertation_Func_1D(
    L=20, N=5001, T=10, dt=0.001, k = 1000, alpha=1000000, m0=0.5,
    init_type="tanh", steepness=.85, perc=0.4,
    t_start=2, t_end=9, num_points=200
)
model_05_100_a100.solve() 
model_05_100_a100.estimate_wave_speed(plot=True)
model_05_100_a100.plot_u_m_with_custom_style([0, 100,200, 300, 400, 500], head_length=1.5, head_width=.65)
# Out:
# Estimated speed = 0.5882, R² = 1.0000
# Estimated speed = 0.5882, R² = 1.0000

# %%
model_05_100_a100.plot_u_m_with_custom_style([0, 1], head_length=1.5, head_width=.65)
