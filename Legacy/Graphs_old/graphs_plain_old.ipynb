# %%
from Plain import Dissertation_Plain_1D

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# <h2> M0 = 0.5

# %%
model_05_01 = Dissertation_Plain_1D(
    L=200, N=5001, T=200, dt=0.1, k = 0.01,
    init_type="tanh", steepness=.85, perc=0.4,
    t_start=20, t_end=180, num_points=200
)
model_05_01.solve()
model_05_01.estimate_wave_speed(plot=True)
model_05_01.plot_u_m_with_custom_style([0, 100,200, 300, 400, 500], head_length=1.5, head_width=.65)
# Out:
# Estimated speed = 1.0035, R² = 1.0000
# Estimated speed = 1.0035, R² = 1.0000

# %%
model_05_10model_05_01 = Dissertation_Plain_1D(
    L=200, N=5001, T=200, dt=0.1, k = 0.1,
    init_type="tanh", steepness=.85, perc=0.4,
    t_start=20, t_end=180, num_points=200
)
model_05_01.solve()
model_05_01.estimate_wave_speed(plot=True)
model_05_01.plot_u_m_with_custom_style([0, 100,200, 300, 400, 500], head_length=1.5, head_width=.65)
# Out:
# Estimated speed = 1.0035, R² = 1.0000
# Estimated speed = 1.0035, R² = 1.0000

# %%
model_05_1 = Dissertation_Plain_1D(
    L=200, N=5001, T=200, dt=0.1, k = 1,
    init_type="tanh", steepness=.85, perc=0.4,
    t_start=20, t_end=180, num_points=200
)
model_05_1.solve()
model_05_1.estimate_wave_speed(plot=True)
model_05_1.plot_u_m_with_custom_style([0, 100,200, 300, 400, 500], head_length=1.5, head_width=.65)
# Out:
# Estimated speed = 1.0034, R² = 1.0000
# Estimated speed = 1.0034, R² = 1.0000

# %%
model_05_10 = Dissertation_Plain_1D(
    L=200, N=5001, T=200, dt=0.1, k = 10,
    init_type="tanh", steepness=.85, perc=0.4,
    t_start=20, t_end=180, num_points=200
)
model_05_10.solve()
model_05_10.estimate_wave_speed(plot=True)
model_05_10.plot_u_m_with_custom_style([0, 100,200, 300, 400, 500], head_length=1.5, head_width=.65)
# Out:
# Estimated speed = 1.0031, R² = 1.0000
# Estimated speed = 1.0031, R² = 1.0000

# %%
model_05_100 = Dissertation_Plain_1D(
    L=50, N=1251, T=100, dt=0.01, k = 100,
    init_type="tanh", steepness=.85, perc=0.4,
    t_start=20, t_end=80, num_points=200
)
model_05_100.solve()
model_05_100.estimate_wave_speed(plot=True)
model_05_100.plot_u_m_with_custom_style([0, 100,200, 300, 400, 500], head_length=1.5, head_width=.65)
# Out:
# Estimated speed = 1.0137, R² = 0.9999
# Estimated speed = 1.0137, R² = 0.9999

# %%
model_05_1000 = Dissertation_Plain_1D(
    L=50, N=1251, T=100, dt=0.01, k = 1000,
    init_type="tanh", steepness=.85, perc=0.4,
    t_start=20, t_end=80, num_points=200
)
model_05_1000.solve()
model_05_1000.estimate_wave_speed(plot=True)
model_05_1000.plot_u_m_with_custom_style([0, 100,200, 300, 400, 500], head_length=1.5, head_width=.65)
# Out:
# Estimated speed = 1.0175, R² = 0.9996
# Estimated speed = 1.0175, R² = 0.9996

# %%
model_05_1000.plot_u_m_with_custom_style([0], head_length=1.5, head_width=.65)

# %%
model_05_1000.plot_u_m_with_custom_style([0, 100], head_length=1.5, head_width=.65)

# %% [markdown]
# <h2> M0=0

# %%
model_00_001 = Dissertation_Plain_1D(
    L=200, N=5001, T=200, dt=0.1, k = 0.01, m0=0.0,
    init_type="tanh", steepness=.85, perc=0.4,
    t_start=20, t_end=180, num_points=200
)
model_00_001.solve()
model_00_001.estimate_wave_speed(plot=True)
model_00_001.plot_u_m_with_custom_style([0, 100,200, 300, 400, 500], head_length=1.5, head_width=.65)
# Out:
# Estimated speed = 0.5773, R² = 0.9982
# Estimated speed = 0.5773, R² = 0.9982

# %%
model_00_01 = Dissertation_Plain_1D(
    L=200, N=5001, T=200, dt=0.1, k = 0.1, m0=0.0,
    init_type="tanh", steepness=.85, perc=0.4,
    t_start=20, t_end=35, num_points=200
)
model_00_01.solve()
model_00_01.estimate_wave_speed(plot=True)
model_00_01.plot_u_m_with_custom_style([0, 100,200, 300, 400, 500], head_length=1.5, head_width=.65)
# Out:
# Estimated speed = 0.5858, R² = 1.0000
# Estimated speed = 0.5858, R² = 1.0000

# %%
model_00_1 = Dissertation_Plain_1D(
    L=200, N=5001, T=200, dt=0.1, k = 1, m0=0.0,
    init_type="tanh", steepness=.85, perc=0.4,
    t_start=20, t_end=35, num_points=200
)
model_00_1.solve()
model_00_1.estimate_wave_speed(plot=True)
model_00_1.plot_u_m_with_custom_style([0, 100,200, 300, 400, 500], head_length=1.5, head_width=.65)
# Out:
# Estimated speed = 0.5858, R² = 1.0000
# Estimated speed = 0.5858, R² = 1.0000

# %%
model_00_10 = Dissertation_Plain_1D(
    L=200, N=5001, T=200, dt=0.1, k = 10, m0=0.0,
    init_type="tanh", steepness=.85, perc=0.4,
    t_start=20, t_end=35, num_points=200
)
model_00_10.solve()
model_00_10.estimate_wave_speed(plot=True)
model_00_10.plot_u_m_with_custom_style([0, 100,200, 300, 400, 500], head_length=1.5, head_width=.65)
# Out:
# Estimated speed = 0.5858, R² = 1.0000
# Estimated speed = 0.5858, R² = 1.0000

# %%
model_00_100 = Dissertation_Plain_1D(
    L=200, N=5001, T=200, dt=0.1, k = 100, m0=0.0,
    init_type="tanh", steepness=.85, perc=0.4,
    t_start=20, t_end=35, num_points=200
)
model_00_100.solve()
model_00_100.estimate_wave_speed(plot=True)

model_00_100.plot_u_m_with_custom_style([0, 100,200, 300, 400, 500], head_length=1.5, head_width=.65)
# Out:
# Estimated speed = 0.5858, R² = 1.0000
# Estimated speed = 0.5858, R² = 1.0000

# %%
model_00_1000 = Dissertation_Plain_1D(
    L=200, N=5001, T=200, dt=0.1, k = 1000, m0=0.0,
    init_type="tanh", steepness=.85, perc=0.4,
    t_start=20, t_end=35, num_points=200
)
model_00_1000.solve()
model_00_1000.estimate_wave_speed(plot=True)
model_00_1000.plot_u_m_with_custom_style([0, 100,200, 300, 400, 500], head_length=1.5, head_width=.65)
# Out:
# Estimated speed = 0.5858, R² = 1.0000
# Estimated speed = 0.5858, R² = 1.0000

# %%
model_00_10000 = Dissertation_Plain_1D(
    L=200, N=5001, T=200, dt=0.1, k = 10000, m0=0.0,
    init_type="tanh", steepness=.85, perc=0.4,
    t_start=20, t_end=35, num_points=200
)
model_00_10000.solve()
model_00_10000.estimate_wave_speed(plot=True)
model_00_10000.plot_u_m_with_custom_style([0, 100,200, 300, 400, 500], head_length=1.5, head_width=.65)
# Out:
# Estimated speed = 0.5858, R² = 1.0000
# Estimated speed = 0.5858, R² = 1.0000

# %% [markdown]
# <h2> M0 = 1

# %%
model_1_001 = Dissertation_Plain_1D(
    L=200, N=5001, T=200, dt=0.1, k = 0.01, m0=1,
    init_type="tanh", steepness=.85, perc=0.4,
    t_start=40, t_end=180, num_points=200
)
model_1_001.solve()
model_1_001.estimate_wave_speed(plot=True)
model_1_001.plot_u_m_with_custom_style([0, 100,200, 300, 400, 500], head_length=1.5, head_width=.65)
# Out:
# Estimated speed = 0.0498, R² = 1.0000
# Estimated speed = 0.0498, R² = 1.0000

# %%
model_1_01 = Dissertation_Plain_1D(
    L=200, N=5001, T=200, dt=0.1, k = 0.1, m0=1,
    init_type="tanh", steepness=.85, perc=0.4,
    t_start=40, t_end=180, num_points=200
)
model_1_01.solve()
model_1_01.estimate_wave_speed(plot=True)
model_1_01.plot_u_m_with_custom_style([0, 100,200, 300, 400, 500], head_length=1.5, head_width=.65)
# Out:
# Estimated speed = 0.1089, R² = 1.0000
# Estimated speed = 0.1089, R² = 1.0000

# %%
model_1_01.plot_u_m_with_custom_style([0, 100,200, 300, 400, 500, 1000], head_length=1.5, head_width=.65)

# %%
model_1_1 = Dissertation_Plain_1D(
    L=200, N=5001, T=200, dt=0.1, k = 1, m0=1,
    init_type="tanh", steepness=.85, perc=0.4,
    t_start=40, t_end=180, num_points=200
)
model_1_1.solve()
model_1_1.estimate_wave_speed(plot=True)
model_1_1.plot_u_m_with_custom_style([0, 100,200, 300, 400, 500], head_length=1.5, head_width=.65)
# Out:
# Estimated speed = 0.1913, R² = 1.0000
# Estimated speed = 0.1913, R² = 1.0000

# %%
model_1_10 = Dissertation_Plain_1D(
    L=200, N=5001, T=200, dt=0.1, k = 10, m0=1,
    init_type="tanh", steepness=.85, perc=0.4,
    t_start=40, t_end=180, num_points=200
)
model_1_10.solve()
model_1_10.estimate_wave_speed(plot=True)
model_1_10.plot_u_m_with_custom_style([0, 100,200, 300, 400, 500], head_length=1.5, head_width=.65)
# Out:
# Estimated speed = 0.2222, R² = 1.0000
# Estimated speed = 0.2222, R² = 1.0000

# %%
model_1_100 = Dissertation_Plain_1D(
    L=50, N=1251, T=75, dt=0.01, k = 100, m0=1,
    init_type="tanh", steepness=.85, perc=0.4,
    t_start=40, t_end=180, num_points=200
)
model_1_100.solve()
model_1_100.estimate_wave_speed(plot=True)
model_1_100.plot_u_m_with_custom_style([0, 100,200, 300, 400, 500], head_length=1.5, head_width=.65)
# Out:
# Estimated speed = 0.5288, R² = 1.0000
# Estimated speed = 0.5288, R² = 1.0000

# %%
model_1_1000 = Dissertation_Plain_1D(
    L=50, N=1251, T=75, dt=0.001, k = 1000, m0=1,
    init_type="tanh", steepness=.85, perc=0.4,
    t_start=40, t_end=180, num_points=200
)
model_1_1000.solve()
model_1_1000.estimate_wave_speed(plot=True)
model_1_1000.plot_u_m_with_custom_style([0, 100,200, 300, 400, 500], head_length=1.5, head_width=.65)
# Out:
# Estimated speed = 0.5636, R² = 0.9999
# Estimated speed = 0.5636, R² = 0.9999

# %%
model_1_1000.plot_u_m_with_custom_style([0,300, 600, 900, 1200], head_length=1.5, head_width=.65)

# %%
model_1_1000.plot_u_m_with_custom_style([0, 50, 1200, 2400], head_length=1.5, head_width=.65)

# %%
model_1_10000 = Dissertation_Plain_1D(
    L=50, N=1251, T=75, dt=0.001, k = 1000, m0=1,
    init_type="tanh", steepness=.85, perc=0.4,
    t_start=40, t_end=100, num_points=200
)
model_1_10000.solve()
model_1_10000.estimate_wave_speed(plot=True)
model_1_10000.plot_u_m_with_custom_style([0, 100,200, 300, 400, 500], head_length=1.5, head_width=.65)
# Out:
# /Users/chamundeshwarivadamalai/Desktop/Oxford/Dissertation/Main/Dissertation_main/New/Dissertation/Graphs/Plain.py:110: RuntimeWarning: invalid value encountered in add
#   M_next = M_curr + self.dt * g_curr
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[67], line 6
#       1 model_1_10000 = Dissertation_Plain_1D(
#       2     L=50, N=1251, T=75, dt=0.001, k = 10000, m0=1,
#       3     init_type="tanh", steepness=.85, perc=0.4,
#       4     t_start=20, t_end=35, num_points=200
#       5 )
# ----> 6 model_1_10000.solve()
#       7 model_1_10000.estimate_wave_speed(plot=True)
#       8 model_1_10000.plot_u_m_with_custom_style([0, 100,200, 300, 400, 500], head_length=1.5, head_width=.65)
#
# File ~/Desktop/Oxford/Dissertation/Main/Dissertation_main/New/Dissertation/Graphs/Plain.py:106, in Dissertation_Plain_1D.solve(self)
# ...

# %% [markdown]
# <h2> M0=.99

# %%
model_099_001 = Dissertation_Plain_1D(
    L=200, N=5001, T=200, dt=0.1, k = 0.01, m0=.9,
    init_type="step", steepness=.85, perc=0.4,
    t_start=20, t_end=180, num_points=200
)
model_099_001.solve()
model_099_001.estimate_wave_speed(plot=True)
model_099_001.plot_u_m_with_custom_style([0, 100,200, 300, 400, 500], head_length=1.5, head_width=.65)
# Out:
# Estimated speed = 0.5917, R² = 1.0000
# Estimated speed = 0.5917, R² = 1.0000

# %%
modelt = Dissertation_Plain_1D(
    L=200, N=5001, T=200, dt=0.1, k = 0.01, m0=.999,
    init_type="step", steepness=.85, perc=0.4,
    t_start=20, t_end=180, num_points=200
)
modelt.solve()
modelt.estimate_wave_speed(plot=True)
modelt.plot_u_m_with_custom_style([0, 100,200, 300, 400, 500], head_length=1.5, head_width=.65)
# Out:
# Estimated speed = 0.0723, R² = 1.0000
# Estimated speed = 0.0723, R² = 1.0000

# %%
model1t = Dissertation_Plain_1D(
    L=200, N=5001, T=200, dt=0.1, k = 0.01, m0=1,
    init_type="step", steepness=.85, perc=0.4,
    t_start=20, t_end=180, num_points=200
)
model1t.solve()
model1t.estimate_wave_speed(plot=True)
model1t.plot_u_m_with_custom_style([0, 100,200, 300, 400, 500], head_length=1.5, head_width=.65)
# Out:
# Estimated speed = 0.0496, R² = 1.0000
# Estimated speed = 0.0496, R² = 1.0000

# %%
model_05_100 = Dissertation_Plain_1D(
    L=50, N=5001, T=100, dt=0.01, k = 100,
    init_type="tanh", steepness=.85, perc=0.4,
    t_start=20, t_end=31, num_points=200
)
model_05_100.solve()
model_05_100.estimate_wave_speed(plot=True)
model_05_100.plot_u_m_with_custom_style([0, 100,200, 300, 400, 500], head_length=1.5, head_width=.65)
# Out:
# Estimated speed = 1.0117, R² = 1.0000
# Estimated speed = 1.0117, R² = 1.0000

# %%
model_05_1000 = Dissertation_Plain_1D(
    L=50, N=5001, T=100, dt=0.001, k = 1000,
    init_type="tanh", steepness=.85, perc=0.4,
    t_start=20, t_end=31, num_points=200
)
model_05_1000.solve()
model_05_1000.estimate_wave_speed(plot=True)
model_05_1000.plot_u_m_with_custom_style([0, 100,200, 300, 400, 500], head_length=1.5, head_width=.65)
# Out:
# Estimated speed = 1.0097, R² = 1.0000
# Estimated speed = 1.0097, R² = 1.0000

# %%
model_01_1000 = Dissertation_Plain_1D(
    L=50, N=5001, T=100, dt=0.001, k = 1000, m0 = 0.1,
    init_type="tanh", steepness=.85, perc=0.4,
    t_start=20, t_end=31, num_points=200
)
model_01_1000.solve()
model_01_1000.estimate_wave_speed(plot=True)
model_01_1000.plot_u_m_with_custom_style([0, 100,200, 300, 400, 500], head_length=1.5, head_width=.65)
# Out:
# Estimated speed = 0.7412, R² = 1.0000
# Estimated speed = 0.7412, R² = 1.0000

# %%
2*(0.1*0.9)**0.5
# Out:
# 0.6000000000000001

# %%
model_05_1000.estimate_wave_speed(plot=True, target='M', threshold= 0.25)
# Out:
# Estimated speed = 1.0244, R² = 0.9996
# (np.float64(1.0243656869728563),
#  np.float64(23.322043259484314),
#  np.float64(0.9995536439631887))

# %%
model_05_10000 = Dissertation_Plain_1D(
    L=10, N=15001, T=10, dt=0.001, k = 10000,
    init_type="tanh", steepness=.85, perc=0.4,
    t_start=3, t_end=8, num_points=200
)
model_05_10000.solve()
model_05_10000.estimate_wave_speed(plot=True)
model_05_10000.plot_u_m_with_custom_style([0, 100,200, 300, 400, 500], head_length=1.5, head_width=.65)
# Out:
# Estimated speed = 0.5920, R² = 1.0000
# Estimated speed = 0.5920, R² = 1.0000

# %%
model_05_10000.plot_u_m_with_custom_style([0, 1000], head_length=1.5, head_width=.65)
